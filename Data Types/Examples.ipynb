# %%
# floating data type

height = 5.9
print(height)
print(type(height))
# Out:
# 5.9
# <class 'float'>

# %%
# string data type

name = "Aryan"
print(name)
print(type(name))
# Out:
# Aryan
# <class 'str'>

# %%
# Boolean data type
is_student = True
print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
a = 10
b = 10

type(a==b)
# Out:
# bool

# %%
# common errors

result = "Aryan" + str(25)
print(result)
# Out:
# Aryan25
