# %% [markdown]
# # Introduction to Function

# %% [markdown]
# #### A function is a block of code that performs a specific task. Function help in organizing code, reusing code, and improving readadility

# %%
# Syntax

def function_name(parameters):
    """docstring"""
    function_body
return value

# %%
def function(age):
    """find if a person is minor or adult"""
    if age < 18:
        print("you are a minor")
    else:
        print("you are adult")

function(20)

function(15)
# Out:
# you are adult
# you are a minor

# %%
# function with multiple parameters

def add(a, b):
    return a + b

result = add(5, 10)
print("Sum:", result)
# Out:
# Sum: 15

# %%
# Default parameters

def greet(name):
    print(f"hello {name} Welcome to pyton programming")

greet("Aryan")      # if we not pass any argument it will take defult name "Guest"
# Out:
# hello Aryan Welcome to pyton programming
