# %% [markdown]
# ## Syntax

# %%
variable_name = value

# %% [markdown]
# Example

# %%
x = 10
name = "Aryan"
pi = 3.14
is_pass = True

# %%
valid_name = 5
_name = 10
# 1num = 4 ❌ invalid

# %%
# python does not need type declaration. It is a dynamically typed language

x = 10       # int
x = "hello"  # now str
