# %%
# Basic Syntax Rules in Python

name = "aryan"
Name = "Aryan"

print(name)
print(Name)
# Out:
# aryan
# Aryan

# %%
# indentation
#  python uses indentation to define blocks of code.Consistent use of spaces (usually 4 spaces) or a tab is required.

if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
#  line Continuation

total = 1 + 2 + 3 + \
    4 + 5
print(total)
# Out:
# 15

# %%
# Multiple Statements in a Single Line

x = 5; y = 10; print(x + y)
# Out:
# 15

# %%
# understanding semnatics in python
# variable saaignment

a = 10
name = "Aryan"

# %%
# Type in ference

variable= 20
print(type(variable))
variable = "Hello"
print(type(variable))
variable = 15.5
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
